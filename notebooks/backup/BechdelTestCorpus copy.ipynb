# %%
import sys; sys.path.insert(0,'..')
from bechdeltest import *

# %%
import lltk
C=lltk.Corpus('bechdel_test')

# %%
C.t.dialogue()
# Out:
# [BechdelTest] Loading corpus:   0%|          | 0/34 [00:00<?, ?it/s]
#                                              speaker  \
# line_num
# 1                          flash crosses the SCREEN.
# 2         fear. The HUNTING PARTY follows them, then
# 3                                        WIDER ANGLE
# 4                                           SUPERMAN
# 5              HUNTING PARTY below. CLOSE ON HUNTERS
# ...                                              ...
# 618                                           LUTHOR
# 619                                              EVE
# 620                                           LUTHOR
# 621                                           LUTHOR
# 622                                              EVE
#
#                                                      speech  \
# line_num
# 1         EXT. BRITISH COUNTRYSIDE - DAY A pack of hound...
# 2         rein their horses back suddenly. They look O.S...
# ...

# %%
# idx='2562232'
# from imdb import Cinemagoer
# ia = Cinemagoer()
# movie = ia.get_movie(idx)
# movie.keys()

# %% [markdown]
# ## Compiling

# %% [markdown]
# ### Step 1: Run movie script database

# %%
BTC = BechdelTestCorpus()
t=BTC.t
t.meta
# Out:
# [BechdelTest] Loading corpus:   0%|          | 0/34 [00:00<?, ?it/s]
# {'_id': '_bechdel_test/HellboyIITheGoldenArmy-2008',
#  '_corpus': 'bechdel_test',
#  'id': 'HellboyIITheGoldenArmy-2008',
#  'correct_imdb': 'tt0411477',
#  'file_name': 'Hellboy-2-The-Golden-Army',
#  'genrenote': 'SUPERHERO',
#  'imdbID': 411477,
#  'rating': 7,
#  'script_url': 'https://imsdb.com/scripts/Hellboy-2-The-Golden-Army.html',
#  'source': 'imsdb',
#  'subgenre': 'superhero?',
#  'title': 'Hellboy II: The Golden Army',
#  'votes': 269406,
#  'year': 2008}

# %%
t.dialogue()
# Out:
#                             speaker  \
# line_num
# 1             MANHATTAN. 10.30 P.M.
# 2         BLACKWOOD'S AUCTION HOUSE
# 3                    SHADOWY FIGURE
# 4                    SHADOWY FIGURE
# 5                        AUCTIONEER
# ...                             ...
# 781                         HELLBOY
# 782                             LIZ
# 783                         HELLBOY
# 784                             LIZ
# 785                         HELLBOY
#
#                                                      speech  \
# line_num
# 1         Park Avenue in mid-December. On the lampposts,...
# 2         Under black umbrellas, wealthy men and women e...
# 3         I'll go up first. You'll enter from below- He ...
# 4                                        And remember Wink-
# 5         Pre-Celtic votive sculpture is in granite and ...
# ...                                                     ...
# 781                                             Milk? Yech.
# ...
