# %% [markdown]
# # Movie Script DB
#
# Following instructions [here](https://github.com/Aveek-Saha/Movie-Script-Database) for assembly. Afterwards...

# %%
# import
import sys; sys.path.insert(0,'..')
from bechdeltest import *
PATH_MOVIESCRIPT_ORIG = '/Users/ryan/data/moviedb/Movie-Script-Database/scripts/'

# %%
def postproc_moviescriptdb_metadata():
    # Read metadata
    meta_fn=os.path.join(PATH_MOVIESCRIPT_ORIG,'metadata','clean_parsed_meta.json')
    with open(meta_fn) as f: data = json.load(f)

    def parse_rowd(rowd):
        odx = {}
        for keytype in rowd:
            for key,val in rowd[keytype].items():
                #odx[f'{keytype}_{key}'] = val
                odx[key] = val
        return odx

    index = data.keys()
    rows = [parse_rowd(data[idx]) for idx in index]
    df = pd.DataFrame(rows, index=index).rename_axis('id_orig')
    df['id'] = df.file_name
    df = df.set_index('id').drop('dialogue	charinfo	tagged name'.split(), axis=1)
    df = df[['title','release_date','source', 'script_url', 'file_name', 'overview']]
    df.to_csv(PATH_CORPUS_METADATA)
    return df

# %%
df = postproc_moviescriptdb_metadata()
df
# Out:
#                                                           title release_date  \
# id
# 10-Things-I-Hate-About-You           10 Things I Hate About You         1999
# 12-and-Holding                                   12 and Holding         2005
# 12-Monkeys                                           12 Monkeys         1995
# 12-Years-a-Slave                               12 Years a Slave         2013
# 127-Hours                                             127 Hours         2010
# ...                                                         ...          ...
# Scandal-Early-Pilot-2-TV-Script-PDF                   Scandal 2         2016
# Scandal-Final-Pilot-TV-Script-PDF                       Scandal         2012
# Scandal-Episode-301-TV-Script-PDF                     Scandal 3         2014
# Ted-Lasso                                             Ted Lasso         2020
# This-Is-Us                                           This Is Us         2016
#
#                                          source  \
# id
# 10-Things-I-Hate-About-You                imsdb
# 12-and-Holding                            imsdb
# 12-Monkeys                           actorpoint
# 12-Years-a-Slave                          imsdb
# 127-Hours                                 imsdb
# ...                                         ...
# Scandal-Early-Pilot-2-TV-Script-PDF   scriptpdf
# Scandal-Final-Pilot-TV-Script-PDF     scriptpdf
# Scandal-Episode-301-TV-Script-PDF     scriptpdf
# Ted-Lasso                             scriptpdf
# This-Is-Us                            scriptpdf
#
#                                                                             script_url  \
# id
# 10-Things-I-Hate-About-You           https://imsdb.com/scripts/10-Things-I-Hate-Abo...
# 12-and-Holding                           https://imsdb.com/scripts/12-and-Holding.html
# 12-Monkeys                           https://www.actorpoint.com/movie-scripts/scrip...
# 12-Years-a-Slave                       https://imsdb.com/scripts/12-Years-a-Slave.html
# 127-Hours                                     https://imsdb.com/scripts/127-Hours.html
# ...                                                                                ...
# Scandal-Early-Pilot-2-TV-Script-PDF  https://script-pdf.s3-us-west-2.amazonaws.com/...
# Scandal-Final-Pilot-TV-Script-PDF    https://script-pdf.s3-us-west-2.amazonaws.com/...
# Scandal-Episode-301-TV-Script-PDF    https://script-pdf.s3-us-west-2.amazonaws.com/...
# Ted-Lasso                            https://script-pdf.s3-us-west-2.amazonaws.com/...
# This-Is-Us                           https://s3-us-west-2.amazonaws.com/script-pdf/...
#
#                                                                file_name  \
# id
# 10-Things-I-Hate-About-You                    10-Things-I-Hate-About-You
# 12-and-Holding                                            12-and-Holding
# 12-Monkeys                                                    12-Monkeys
# 12-Years-a-Slave                                        12-Years-a-Slave
# 127-Hours                                                      127-Hours
# ...                                                                  ...
# Scandal-Early-Pilot-2-TV-Script-PDF  Scandal-Early-Pilot-2-TV-Script-PDF
# Scandal-Final-Pilot-TV-Script-PDF      Scandal-Final-Pilot-TV-Script-PDF
# Scandal-Episode-301-TV-Script-PDF      Scandal-Episode-301-TV-Script-PDF
# Ted-Lasso                                                      Ted-Lasso
# This-Is-Us                                                    This-Is-Us
#
#                                                                               overview
# id
# 10-Things-I-Hate-About-You           On the first day at his new school, Cameron in...
# 12-and-Holding                       Three pre-adolescents with virginal and eager-...
# 12-Monkeys                           In the year 2035, convict James Cole reluctant...
# 12-Years-a-Slave                     In the pre-Civil War United States, Solomon No...
# 127-Hours                            The true story of mountain climber Aron Ralsto...
# ...                                                                                ...
# Scandal-Early-Pilot-2-TV-Script-PDF
# Scandal-Final-Pilot-TV-Script-PDF    An English bon-vivant osteopath is enchanted w...
# Scandal-Episode-301-TV-Script-PDF                                                  NaN
# Ted-Lasso                            Ted Lasso, an American football coach, moves t...
# This-Is-Us                           Follows the lives and families of three adults...
#
# [2109 rows x 6 columns]

# %% [markdown]
# ## Postproc files

# %%
def postproc_moviescriptdb_files():
    df['path_csv'] = df.file_name.apply(
        lambda x: os.path.join(PATH_MOVIESCRIPT_ORIG,'parsed_movie_scripts', x+'.csv')
    )
    objs = list(df.path_csv)#[:2]
    pmap(do_postproc_moviescriptdb_files, objs, num_proc=1)


def do_postproc_moviescriptdb_files(fn):
    if not os.path.exists(fn): return
    fnid=os.path.splitext(os.path.basename(fn))[0]
    odir=os.path.join(PATH_CORPUS_TEXTS,fnid)
    if not os.path.exists(odir): os.makedirs(odir)
    ofn = os.path.join(odir, f'{fnid}.dialogue.csv')
    shutil.copy(fn, ofn)

# %%
postproc_moviescriptdb_files()
# Out:
# Mapping do_postproc_moviescriptdb_files() [x1]:   0%|          | 0/2109 [00:00<?, ?it/s]

# %%
# df.to_csv('data.movie_script_db.csv')
